# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnyday2/challenge2_data_science_TelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Challenge ONE Data Science – Telecom X**

# %% [markdown]
# ## **💡Acerca del desafío 💡**

# %% [markdown]
# **Telecom X - Análisis de Evasión de Clientes**
#
# Has sido contratado como asistente de análisis de datos en Telecom X y formarás parte del proyecto **"Churn de Clientes"**. La empresa enfrenta una alta tasa de cancelaciones y necesita comprender los factores que llevan a la pérdida de clientes.
#
# Tu desafío será recopilar, procesar y analizar los datos, utilizando Python y sus principales bibliotecas para extraer información valiosa. A partir de tu análisis, el equipo de Data Science podrá avanzar en modelos predictivos y desarrollar estrategias para reducir la evasión.
#
# ¿Qué vas a practicar?
#
# ✅ **Importar y manipular datos** desde una API de manera eficiente.
#
# ✅ **Aplicar los conceptos de ETL** (Extracción, Transformación y Carga) en la preparación de los datos.
#
# ✅ **Crear visualizaciones** estratégicas para identificar patrones y tendencias.
#
# ✅ **Realizar un Análisis Exploratorio de Datos (EDA)** y generar un informe con insights relevantes.
#
#
# ¡Ahora es tu turno! 🚀 Usa tus conocimientos para transformar datos en información estratégica y ayudar a **Telecom X** a retener más clientes.

# %% [markdown]
# ## **Diccionario de datos**

# %% [markdown]
# *   **customerID**: número de identificación único de cada cliente
# *   **Churn**: si el cliente dejó o no la empresa
# *   **gender**: género (masculino y femenino)
# *   **SeniorCitizen**: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
# *   **Partner**: si el cliente tiene o no una pareja
# *   **Dependents**: si el cliente tiene o no dependientes
# *   **tenure**: meses de contrato del cliente
# *   **PhoneService**: suscripción al servicio telefónico
# *   **MultipleLines**: suscripción a más de una línea telefónica
# *   **InternetService**: suscripción a un proveedor de internet
# *   **OnlineSecurity**: suscripción adicional de seguridad en línea
# *   **OnlineBackup**: suscripción adicional de respaldo en línea
# *   **DeviceProtection**: suscripción adicional de protección del dispositivo
# *   **TechSupport**: suscripción adicional de soporte técnico, menor tiempo de espera
# *   **StreamingTV**: suscripción de televisión por cable
# *   **StreamingMovies**: suscripción de streaming de películas
# *   **Contract**: tipo de contrato
# *   **PaperlessBilling**: si el cliente prefiere recibir la factura en línea
# *   **PaymentMethod**: forma de pago
# *   **Charges.Monthly**: total de todos los servicios del cliente por mes
# *   **Charges.Total**: total gastado por el cliente

# %% [markdown]
# ## **📌 Extracción de datos(E - Extract)**

# %% [markdown]
# 📌 Enlace de la API:
#
# [🔗 at main](https://github.com/ingridcristh/challenge2-data-science-LATAM/blob/main/TelecomX_Data.json)  · ingridcristh/challenge2-data-science-LATAM
#
# [🔗GitHub](https://github.com/ingridcristh/challenge2-data-science-LATAM)- ingridcristh/challenge2-data-science-LATAM

# %% [markdown]
# ### **¿Qué debes hacer?**

# %% [markdown]
# ✅ Cargar los datos directamente desde la API utilizando Python.
#
# ✅ Convertir los datos a un DataFrame de Pandas para facilitar su manipulación.

# %%
import requests
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/ingridcristh/challenge2-data-science/refs/heads/main/TelecomX_Data.json"
response = requests.get(url)
data_json = response.json()

data_json
# Out:
# [{'customerID': '0002-ORFBO',
#   'Churn': 'No',
#   'customer': {'gender': 'Female',
#    'SeniorCitizen': 0,
#    'Partner': 'Yes',
#    'Dependents': 'Yes',
#    'tenure': 9},
#   'phone': {'PhoneService': 'Yes', 'MultipleLines': 'No'},
#   'internet': {'InternetService': 'DSL',
#    'OnlineSecurity': 'No',
#    'OnlineBackup': 'Yes',
#    'DeviceProtection': 'No',
#    'TechSupport': 'Yes',
#    'StreamingTV': 'Yes',
#    'StreamingMovies': 'No'},
#   'account': {'Contract': 'One year',
#    'PaperlessBilling': 'Yes',
#    'PaymentMethod': 'Mailed check',
#    'Charges': {'Monthly': 65.6, 'Total': '593.3'}}},
#  {'customerID': '0003-MKNFE',
#   'Churn': 'No',
#   'customer': {'gender': 'Male',
#    'SeniorCitizen': 0,
#    'Partner': 'No',
#    'Dependents': 'No',
#    'tenure': 9},
#   'phone': {'PhoneService': 'Yes', 'MultipleLines': 'Yes'},
#   'internet': {'InternetService': 'DSL',
#    'OnlineSecurity': 'No',
#    'OnlineBackup': 'No',
#    'DeviceProtection': 'No',
# ...

# %%
print(type(data_json))
# Out:
# <class 'list'>

# %%
datos = pd.json_normalize(data_json)
datos.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
datos.info() # o datos.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %% [markdown]
# ## **🔧 Transformación (T - Transform)**

# %% [markdown]
# **¿Qué debes hacer?**

# %% [markdown]
# ✅ Explorar las columnas del dataset y verificar sus tipos de datos.
#
# ✅ Consultar el diccionario para comprender mejor el significado de las variables.
#
# ✅ Identificar las columnas más relevantes para el análisis de evasión.

# %% [markdown]
# ### **Conoce el conjunto de datos**

# %%
# revisar si alguna de las columnas contiene valores nulos
datos.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %%
from os import replace
# reemplazar las comas (por si hay) y espacios por nada y eliminar los epacios de la cadena
datos['account.Charges.Total'] = datos['account.Charges.Total'].apply(lambda x: x.replace(' ', '').replace(',', '').strip())
datos['account.Charges.Total'].sample(5)
# Out:
# 1310     7099
# 1336    422.7
# 80       1147
# 3092    389.8
# 1253     48.6
# Name: account.Charges.Total, dtype: object

# %%
# revisar cuantas cadenas vacias existen
valores_en_blanco_o_vacio = datos.apply(lambda x: x.astype(str).str.strip() == '').sum()
print("\nValores en blanco o string vacios por columna:")
print(valores_en_blanco_o_vacio[valores_en_blanco_o_vacio > 0])
# Out:
# Valores en blanco o string vacios por columna:
# Churn                    224
# account.Charges.Total     11
# dtype: int64

# %%
# revisar cuantas cadenas vacias existen en un campo especifico
valores_vacios = datos.query("`account.Charges.Total` == ''")
print("\nValores en blanco o string vacios por columna:")
print(len(valores_vacios))
# Out:
# Valores en blanco o string vacios por columna:
# 11

# %%
import numpy as np

# Reemplazar cadenas vacías con un 0, para cadenas que seran convertidas a tipo númerico
datos['account.Charges.Total'] = datos['account.Charges.Total'].replace('', '0')
# Convertir a float
datos['account.Charges.Total'] = datos['account.Charges.Total'].astype(np.float64)

# reemplazar cadenas vacias por la cadena 'Desconocido'
datos['Churn'] = datos['Churn'].replace('', 'Desconocido')

# %%
# revisar cuantas cadenas vacias existen en un campo especifico
valores_vacios = datos.query("Churn == ''")
print("\nValores en blanco o string vacios por columna:")
print(len(valores_vacios))
# Out:
# Valores en blanco o string vacios por columna:
# 0

# %%
datos['customer.SeniorCitizen'] = datos['customer.SeniorCitizen'].astype(np.int64)

# %% [markdown]
# ### **Comprobación de incoherencias en los datos**

# %% [markdown]
# En este paso, verifica si hay problemas en los datos que puedan afectar el análisis. Presta atención a valores ausentes, duplicados, errores de formato e inconsistencias en las categorías. Este proceso es esencial para asegurarte de que los datos estén listos para las siguientes etapas.
#
# 📌 Consejos:
# *   pandas.unique()
# *   pandas.Series.dt.normalize()

# %%
# validar si existen los identificadores del cliente duplicados
datos['customerID'].duplicated().any()
# Out:
# np.False_

# %%
datos_total_0 = datos.query('`account.Charges.Monthly` > 0 and `account.Charges.Total` == 0')
len(datos_total_0)
# Out:
# 11

# %%
datos_total_0.sample(10)
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 5599  7644-OMVMY    No            Male                       0
# 2308  3213-VVOLG    No            Male                       0
# 4169  5709-LVOEQ    No          Female                       0
# 2075  2923-ARZLG    No            Male                       0
# 3134  4367-NUYAO    No            Male                       0
# 975   1371-DWPAZ    No          Female                       0
# 1775  2520-SGTTA    No          Female                       0
# 2930  4075-WKNIU    No          Female                       0
# 2232  3115-CZMZD    No            Male                       0
# 3203  4472-LVYGI    No          Female                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 5599              Yes                 Yes                0                Yes
# 2308              Yes                 Yes                0                Yes
# ...

# %% [markdown]
# ### pandas.unique()

# %%
for columna in datos.columns:
  print(f'\n{columna}')
  print(datos[columna].unique())
# Out:
# customerID
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
# Churn
# ['No' 'Yes' 'Desconocido']
#
# customer.gender
# ['Female' 'Male']
#
# customer.SeniorCitizen
# [0 1]
#
# customer.Partner
# ['Yes' 'No']
#
# customer.Dependents
# ['Yes' 'No']
#
# customer.tenure
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
#
# phone.PhoneService
# ['Yes' 'No']
#
# phone.MultipleLines
# ['No' 'Yes' 'No phone service']
#
# internet.InternetService
# ['DSL' 'Fiber optic' 'No']
#
# internet.OnlineSecurity
# ['No' 'Yes' 'No internet service']
#
# internet.OnlineBackup
# ['Yes' 'No' 'No internet service']
#
# internet.DeviceProtection
# ['No' 'Yes' 'No internet service']
#
# internet.TechSupport
# ['Yes' 'No' 'No internet service']
#
# internet.StreamingTV
# ...

# %% [markdown]
# ### **Manejo de inconsistencias**

# %% [markdown]
# Ahora que has identificado las inconsistencias, es momento de aplicar las correcciones necesarias. Ajusta los datos para asegurarte de que estén completos y coherentes, preparándolos para las siguientes etapas del análisis.
#
# 📌 Consejos: Manipulación de strings en pandas: lower, replace, startswith y contains

# %%
filtro1 = datos['account.Charges.Monthly'] == 0
datos_facturacion_0 = datos[filtro1]
len(datos_facturacion_0)
# Out:
# 0

# %% [markdown]
# ### **Columna de cuentas diarias**

# %% [markdown]
# Ahora que los datos están limpios, es momento de crear la columna **"Cuentas_Diarias"**. Utiliza la facturación mensual para calcular el valor diario, proporcionando una visión más detallada del comportamiento de los clientes a lo largo del tiempo.
#
# 📌 Esta columna te ayudará a profundizar en el análisis y a obtener información valiosa para las siguientes etapas.

# %%
datos['Cuentas_Diarias'] = datos['account.Charges.Monthly'] / 30
datos['Cuentas_Diarias'].sample(5)
# Out:
# 4395    0.968333
# 5228    0.688333
# 6837    0.836667
# 6222    0.660000
# 2337    1.490000
# Name: Cuentas_Diarias, dtype: float64

# %% [markdown]
# ### **Estandarización y transformación de datos (opcional)**

# %% [markdown]
# La estandarización y transformación de datos es una etapa opcional, pero altamente recomendada, ya que busca hacer que la información sea más consistente, comprensible y adecuada para el análisis. Durante esta fase, por ejemplo, puedes convertir valores textuales como "Sí" y "No" en valores binarios (1 y 0), lo que facilita el procesamiento matemático y la aplicación de modelos analíticos.
#
# Además, traducir o renombrar columnas y datos hace que la información sea más accesible y fácil de entender, especialmente cuando se trabaja con fuentes externas o términos técnicos. Aunque no es un paso obligatorio, puede mejorar significativamente la claridad y comunicación de los resultados, facilitando la interpretación y evitando confusiones, especialmente al compartir información con stakeholders no técnicos.

# %%
datos = datos.rename(columns={'customer.gender': 'gender', 'customer.SeniorCitizen': 'SeniorCitizen'
                      , 'customer.Partner': 'Partner', 'customer.Dependents': 'Dependents'
                      , 'customer.tenure': 'tenure', 'phone.PhoneService': 'PhoneService'
                      , 'phone.MultipleLines': 'MultipleLines', 'internet.InternetService': 'InternetService'
                      , 'internet.OnlineSecurity': 'OnlineSecurity', 'internet.OnlineBackup': 'OnlineBackup'
                      , 'internet.DeviceProtection': 'DeviceProtection', 'internet.TechSupport': 'TechSupport'
                      , 'internet.StreamingTV': 'StreamingTV', 'internet.StreamingMovies': 'StreamingMovies'
                      , 'account.Contract': 'Contract', 'account.PaperlessBilling': 'PaperlessBilling'
                      , 'account.PaymentMethod': 'PaymentMethod', 'account.Charges.Monthly': 'ChargesMonthly'
                      , 'account.Charges.Total': 'ChargesTotal'
                     }
            )
datos.sample()
# Out:
#       customerID Churn gender  SeniorCitizen Partner Dependents  tenure  \
# 3372  4685-ERGHK    No   Male              0      No         No      57
#
#      PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 3372          Yes           Yes     Fiber optic  ...               No
#
#      TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# 3372          No         Yes              No  One year              Yes
#
#          PaymentMethod ChargesMonthly ChargesTotal  Cuentas_Diarias
# 3372  Electronic check           86.9      4939.25         2.896667
#
# [1 rows x 22 columns]

# %%
# pd.set_option('future.no_silent_downcasting', True)

# %%
datos['Churn'] = datos['Churn'].map({'No': 0, 'Yes': 1, 'Desconocido':-1}).astype(int)
datos['gender'] = datos['gender'].map({'Female': 0, 'Male': 1}).astype(int)
datos['Partner'] = datos['Partner'].map({'No': 0, 'Yes': 1}).astype(int)
datos['Dependents'] = datos['Dependents'].map({'No': 0, 'Yes': 1}).astype(int)
datos['PhoneService'] = datos['PhoneService'].map({'No': 0, 'Yes': 1}).astype(int)
datos['MultipleLines'] = datos['MultipleLines'].map({'No': 0, 'Yes': 1, 'No phone service': -1}).astype(int)
datos['InternetService'] = datos['InternetService'].map({'DSL': 0, 'Fiber optic': 1, 'No': -1}).astype(int)
datos['OnlineSecurity'] = datos['OnlineSecurity'].map({'No': 0, 'Yes': 1, 'No internet service': -1}).astype(int)
datos['OnlineBackup'] = datos['OnlineBackup'].map({'No': 0, 'Yes': 1, 'No internet service': -1}).astype(int)
datos['DeviceProtection'] = datos['DeviceProtection'].map({'No': 0, 'Yes': 1, 'No internet service': -1}).astype(int)
datos['TechSupport'] = datos['TechSupport'].map({'No': 0, 'Yes': 1, 'No internet service': -1}).astype(int)
datos['StreamingTV'] = datos['StreamingTV'].map({'No': 0, 'Yes': 1, 'No internet service': -1}).astype(int)
datos['StreamingMovies'] = datos['StreamingMovies'].map({'No': 0, 'Yes': 1, 'No internet service': -1}).astype(int)
datos['Contract'] = datos['Contract'].map({'Month-to-month': 0, 'One year': 1, 'Two year': 2}).astype(int)
datos['PaperlessBilling'] = datos['PaperlessBilling'].map({'No': 0, 'Yes': 1}).astype(int)
datos['PaymentMethod'] = datos['PaymentMethod'].map({'Electronic check': 0, 'Mailed check': 1, 'Bank transfer (automatic)': 2, 'Credit card (automatic)': 3}).astype(int)

datos.sample(5)
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 3773  5176-OLSKT      0       0              0        1           0      66
# 4275  5879-SESNB      0       0              0        0           0      11
# 1160  1645-EFCGT     -1       1              0        1           1      72
# 1581  2251-PYLPB      0       1              0        1           0      72
# 5545  7595-EUIVN      1       0              0        0           0       1
#
#       PhoneService  MultipleLines  InternetService  ...  DeviceProtection  \
# 3773             1              1                0  ...                 1
# 4275             1              1                1  ...                 0
# 1160             1              0               -1  ...                -1
# 1581             1              1                0  ...                 1
# 5545             1              0                1  ...                 0
#
# ...

# %%
datos.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'ChargesMonthly', 'ChargesTotal',
#        'Cuentas_Diarias'],
#       dtype='object')

# %%
# revisamos si la data esta coerrente y que los clientes con estado
# "Internet Service"=NO no tienen servicios adicionales que corresponden al "Internet Service"=YES
len(datos[(datos['InternetService']==0) & ((datos['OnlineSecurity']==1) | (datos['OnlineBackup']==1)
     | (datos['StreamingTV']==1) | (datos['StreamingMovies']==1))])
# Out:
# 2021

# %%
# revisamos si entre los clientes que todavia no tienen cargos
# existen que tienen permanencia
len(datos[(datos['ChargesTotal']==0) & (datos['tenure']>0)])
# Out:
# 0

# %%
# revisamos si entre los clientes que todavia no tienen cargos
# existen que se evadieron
len(datos[(datos['ChargesTotal']==0) & (datos['Churn']==1)])
# Out:
# 0

# %%
datos[datos['Churn']==0].sample(5) # permanecen
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 4656  6374-NTQLP      0       1              1        1           1      72
# 6016  8216-AZUUZ      0       0              0        1           1      42
# 749   1074-AMIOH      0       0              0        1           1      53
# 6289  8647-SDTWQ      0       1              0        1           1      57
# 896   1264-FUHCX      0       0              0        1           0      49
#
#       PhoneService  MultipleLines  InternetService  ...  DeviceProtection  \
# 4656             1              0                1  ...                 1
# 6016             1              0                1  ...                 1
# 749              1              0                1  ...                 1
# 6289             1              1                1  ...                 0
# 896              0             -1                0  ...                 0
#
# ...

# %%
datos[datos['Churn']==1].sample(5) # evadieron
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 359   0516-VRYBW      1       0              0        0           1      18
# 7030  9681-OXGVC      1       0              0        0           0       5
# 5694  7780-OTDSO      1       1              0        1           0      18
# 3326  4631-OACRM      1       1              1        0           0      15
# 3918  5356-RHIPP      1       1              0        0           0       1
#
#       PhoneService  MultipleLines  InternetService  ...  DeviceProtection  \
# 359              1              0               -1  ...                -1
# 7030             1              1                1  ...                 1
# 5694             1              1                1  ...                 0
# 3326             1              0                1  ...                 0
# 3918             1              0               -1  ...                -1
#
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   int64
#  2   gender            7267 non-null   int64
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   int64
#  5   Dependents        7267 non-null   int64
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   int64
#  8   MultipleLines     7267 non-null   int64
#  9   InternetService   7267 non-null   int64
#  10  OnlineSecurity    7267 non-null   int64
#  11  OnlineBackup      7267 non-null   int64
#  12  DeviceProtection  7267 non-null   int64
#  13  TechSupport       7267 non-null   int64
#  14  StreamingTV       7267 non-null   int64
#  15  StreamingMovies   7267 non-null   int64
# ...

# %% [markdown]
# ### **Análisis Descriptivo**

# %% [markdown]
# Para comenzar, realiza un análisis descriptivo de los datos, calculando métricas como media, mediana, desviación estándar y otras medidas que ayuden a comprender mejor la distribución y el comportamiento de los clientes.
#
# 📌 Consejos:
# DataFrame.describe()

# %%
datos.describe()
# Out:
#              Churn       gender  SeniorCitizen      Partner   Dependents  \
# count  7267.000000  7267.000000    7267.000000  7267.000000  7267.000000
# mean      0.226366     0.505711       0.162653     0.484106     0.300124
# std       0.486627     0.500002       0.369074     0.499782     0.458343
# min      -1.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000     1.000000       0.000000     0.000000     0.000000
# 75%       1.000000     1.000000       0.000000     1.000000     1.000000
# max       1.000000     1.000000       1.000000     1.000000     1.000000
#
#             tenure  PhoneService  MultipleLines  InternetService  \
# count  7267.000000   7267.000000    7267.000000      7267.000000
# mean     32.346498      0.902711       0.324481         0.222513
# std      24.571773      0.296371       0.643295         0.779873
# ...

# %% [markdown]
# ### **Distribución de evasión**

# %% [markdown]
# En este paso, el objetivo es comprender cómo está distribuida la variable "churn" (evasión) entre los clientes. Utiliza gráficos para visualizar la proporción de clientes que permanecieron y los que se dieron de baja.

# %%
# Filtramos los datos, excluyendo a los clientes cuyo estado de permanencia se desconoce,
# ya que estos tienen un porcentaje bajo que no influye en el análisis
filtroChurn = datos['Churn'] != -1 # ['No' 'Yes' 'Desconocido']
datos_churn_filtrados = datos[filtroChurn]
print(f'\nCantidad de clientes:\n{len(datos_churn_filtrados)}')
# Out:
# Cantidad de clientes:
# 7043

# %%
datos_churn_filtrados.describe()
# Out:
#              Churn       gender  SeniorCitizen      Partner   Dependents  \
# count  7043.000000  7043.000000    7043.000000  7043.000000  7043.000000
# mean      0.265370     0.504756       0.162147     0.483033     0.299588
# std       0.441561     0.500013       0.368612     0.499748     0.458110
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000     1.000000       0.000000     0.000000     0.000000
# 75%       1.000000     1.000000       0.000000     1.000000     1.000000
# max       1.000000     1.000000       1.000000     1.000000     1.000000
#
#             tenure  PhoneService  MultipleLines  InternetService  \
# count  7043.000000   7043.000000    7043.000000      7043.000000
# mean     32.371149      0.903166       0.325004         0.222916
# std      24.559481      0.295752       0.642730         0.778877
# ...

# %%
print(f"Cantidad de clientes que permanecen: {datos_churn_filtrados[datos_churn_filtrados['Churn'] == 0].shape[0]}")
print(f"Cantidad de clientes que se fueron: {datos_churn_filtrados[datos_churn_filtrados['Churn'] == 1].shape[0]}")
# Out:
# Cantidad de clientes que permanecen: 5174
# Cantidad de clientes que se fueron: 1869

# %%
# Graficando barras de clientes por permanencia

import matplotlib.pyplot as plt

# Crear el gráfico y guardar el eje
ax = datos_churn_filtrados['Churn'].map({0: 'Permanecen', 1: 'Evadieron'}).value_counts().plot(
    kind='bar',
    color=['lightgreen', 'lightcoral']
)

# Título y etiquetas
plt.title('Distribución por permanencia', fontdict={'fontsize': 16, 'fontweight': 'bold'})
plt.xlabel('Clientes que permanecen vs que evadieron', fontdict={'fontsize': 12})
plt.ylabel('Cantidad', fontdict={'fontsize': 12})

plt.xticks(ticks=[0, 1], labels=['Permanecen', 'Evadieron'], rotation=0)

# Agregar los valores encima de cada barra
for i, p in enumerate(ax.patches):
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2,
            height + 10,              # un poco arriba de la barra
            int(height),              # el número
            ha='center', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# el grupo de edad % y los primeros meses

# %% [markdown]
# ### **Recuento de evasión por variables categóricas**

# %% [markdown]
# Ahora, exploraremos cómo se distribuye la **evasión** según variables categóricas, **como género, tipo de contrato, método de pago, entre otras**.
#
# Este análisis puede revelar **patrones interesantes**, por ejemplo, si los clientes de ciertos perfiles tienen una mayor tendencia a cancelar el servicio, lo que ayudará a **orientar acciones estratégicas**.

# %%
# Evasión según género
# Crear una tabla pivote: filas = gender, columnas = Churn
churn_genero = datos_churn_filtrados.pivot_table(
    index='gender',
    columns='Churn',
    aggfunc='size',
    fill_value=0
)

# Mapear valores si están codificados
churn_genero.index = churn_genero.index.map({0: 'Feminino', 1: 'Masculino'})
churn_genero.columns = ['Permanecen', 'Evadieron']

# Gráfico de barras agrupadas
ax = churn_genero.plot(kind='bar', color=['lightgreen', 'lightcoral'])

plt.title('Distribución por género y permanencia', fontdict={'fontsize': 16, 'fontweight': 'bold'})
plt.xlabel('Género', fontdict={'fontsize': 12})
plt.ylabel('Cantidad', fontdict={'fontsize': 12})
ax.legend(title='', loc='upper right')#, bbox_to_anchor=(1.18, 1.02))

plt.xticks(rotation=0)

# Mostrar valores encima
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Evasión según tipo de contrato
# Crear una tabla pivote: filas = Contract, columnas = Churn
churn_contrato = datos_churn_filtrados.pivot_table(
    index='Contract',
    columns='Churn',
    aggfunc='size',
    fill_value=0
)

# Mapear valores si están codificados
churn_contrato.index = churn_contrato.index.map({0: 'Mes a mes', 1: 'Por un año', 2: 'Por dos años'})
churn_contrato.columns = ['Permanecen', 'Evadieron']

# Gráfico de barras agrupadas
ax = churn_contrato.plot(kind='bar', color=['lightgreen', 'lightcoral'])

plt.title('Distribución por tipo de contrato y permanencia', fontdict={'fontsize': 16, 'fontweight': 'bold'})
plt.xlabel('Tipo de contrato', fontdict={'fontsize': 12})
plt.ylabel('Cantidad', fontdict={'fontsize': 12})
ax.legend(title='', loc='upper right')

plt.xticks(rotation=0)

# Mostrar valores encima
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Evasión según método de pago
import matplotlib.pyplot as plt
import seaborn as sns

# Crear una tabla pivote: filas = Contract, columnas = Churn
churn_metodo = datos_churn_filtrados.pivot_table(
    index='PaymentMethod',
    columns='Churn',
    aggfunc='size',
    fill_value=0
)

# Mapear valores si están codificados
churn_metodo.index = churn_metodo.index.map({0: 'Electronic check', 1: 'Mailed check', 2:'Bank transfer (automatic)', 3: 'Credit card (automatic)'})
churn_metodo.columns = ['Permanecen', 'Evadieron']

# Gráfico de barras agrupadas
ax = churn_metodo.plot(kind='bar', color=['lightgreen', 'lightcoral'])

plt.title('Distribución por método de pago y permanencia', fontdict={'fontsize': 16, 'fontweight': 'bold'})
plt.xlabel('Método de pago', fontdict={'fontsize': 12})
plt.ylabel('Cantidad', fontdict={'fontsize': 12})
ax.legend(title='', loc='upper right')

plt.xticks(rotation=30)

# Mostrar valores encima
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ax = churn_metodo.plot(kind='bar', color={'lightcoral', 'lightgreen'}, xlabel='Método de pago',ylabel='Cantidad')
ax.set(title='Distribución por método de pago y permanencia')
ax.legend(title='', loc='upper right')

plt.xticks(rotation=30)

# Mostrar valores encima
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=8)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Categorías a analizar
categorias = ['gender', 'PaymentMethod', 'Contract']
nombres_categorias = {
    'gender': 'Género',
    'PaymentMethod': 'Método de Pago',
    'Contract': 'Tipo de Contrato'
}
metodo = {
    0: 'Electronic check',
    1: 'Mailed check',
    2: 'Bank transfer (automatic)',
    3: 'Credit card (automatic)'
}
contrato = {
    0: 'Mes a mes',
    1: 'Por un año',
    2: 'Por dos años'
}
genero = {
    0: 'Femenino',
    1: 'Masculino'
}
mapeos = {
    'gender': genero,
    'PaymentMethod': metodo,
    'Contract': contrato
}

# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))
# Guardar las posiciones Y de cada grupo (para las líneas separadoras)
posiciones = []
y_pos = 0

# Iterar por cada categoría
for i, cat in enumerate(categorias):
    grupo = datos_churn_filtrados.groupby([cat, 'Churn']).size().unstack(fill_value=0)

    for j, (valor_cat, fila) in enumerate(grupo.iterrows()):
      # Cantidades absolutas
      permanecen = fila[0]
      evadieron = fila[1]
      total = permanecen + evadieron

      # Proporciones para cada lado (respetando el centro como 0)
      permanecen_prop = permanecen / total
      evadieron_prop = evadieron / total

      # Etiquetas de eje y
      nombre_legible = mapeos[cat].get(valor_cat, valor_cat)  # usa el mapeo si existe, si no, deja el valor original

      '''
      # Plot males to the left (negative values for left side)
      bar_evadieron = ax.barh(f"{nombres_categorias[cat]}: {nombre_legible}", -evadieron_prop
                                  , color='lightcoral', label='Evadieron' if i == 0 and j == 0 else "")

      # Plot females to the right
      bar_permanecen = ax.barh(f"{nombres_categorias[cat]}: {nombre_legible}", permanecen_prop
                                  , color='lightgreen', label='Permanecen' if i == 0 and j == 0 else "")
      '''

      # Plot evadieron (lado izquierdo)
      bar_evadieron = ax.barh(
          f"{nombres_categorias[cat]}: {nombre_legible}",
          -evadieron,   # usar cantidad absoluta
          color='lightcoral',
          label='Evadieron' if i == 0 and j == 0 else ""
      )

      # Plot permanecen (lado derecho)
      bar_permanecen = ax.barh(
          f"{nombres_categorias[cat]}: {nombre_legible}",
          permanecen,   # usar cantidad absoluta
          color='lightgreen',
          label='Permanecen' if i == 0 and j == 0 else ""
      )

      # Aumentar distancia del eje y (más espacio entre el eje y los textos)
      ax.tick_params(axis='y', pad=50)

      # Agregar etiquetas de valores sobre las barras
      bar_left = bar_evadieron[0]
      ax.text(bar_left.get_width() - 0.01,
              bar_left.get_y() + bar_left.get_height()/2,  # ligeramente arriba
              f"{evadieron} ({evadieron_prop:.1%})",
              va='center', ha='right', fontsize=8)

      bar_right = bar_permanecen[0]
      ax.text(bar_right.get_width() + 0.01,
              bar_right.get_y() + bar_right.get_height()/2,
              f"{permanecen} ({permanecen_prop:.1%})",
              va='center', ha='left', fontsize=8)
      y_pos += 1

    posiciones.append(y_pos)  # guarda la posición final de este grupo

# Línea vertical al centro
ax.axvline(0, color='black', linestyle='--', linewidth=1)

# Líneas horizontales separadoras entre bloques
for p in posiciones[:-1]:  # no dibujar después del último grupo
    ax.axhline(p - 0.5, color="gray", linestyle="--", linewidth=1)

# Add labels and title
ax.set_xlabel('Cantidad')
ax.tick_params(axis='y', length=0)  # elimina la longitud de las marcas (ticks)
ax.set_title('Clientes que evadieron vs que permanecen por categoría')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.15), ncol=2)

# Quitar marco (spines)
for spine in ax.spines.values():
    spine.set_visible(False)

# Quitar valores del eje x
ax.set_xticks([])
ax.set_xticklabels([])

# Show the plot
plt.tight_layout(rect=[0, 0.05, 1, 1])  # deja espacio abajo

fig.savefig('permanencia_por_categoria.png'
            , transparent=False, dpi=300, bbox_inches='tight') # fondo blanco, resolucion de 300 y sin margines
plt.show()

# %% [markdown]
# ### **Conteo de evasión por variables numéricas**

# %% [markdown]
# En este paso, explora cómo las variables numéricas, como "total gastado" o "tiempo de contrato", se distribuyen entre los clientes que cancelaron (evasión) y los que no cancelaron.
#
# Este análisis ayuda a entender si ciertos valores numéricos están más asociados con la evasión, proporcionando insights sobre los factores que influyen en el comportamiento de los clientes.

# %%
# Tiempo de contrato
import pandas as pd
import plotly.express as px

# Agrupar la permanencia (tenure) en intervalos de 6 meses
datos_churn_filtrados_interv = datos_churn_filtrados.copy()
datos_churn_filtrados_interv['tenure_interval'] = pd.cut(datos_churn_filtrados_interv['tenure'], bins=range(0, 80, 6))

# Calcular la cantidad de personas que evadieron (Churn == 1)
grupo = datos_churn_filtrados_interv[datos_churn_filtrados_interv['Churn'] == 1] \
    .groupby(['tenure_interval', 'SeniorCitizen'], observed=True) \
    .size().reset_index(name='ChurnCount')

# Convertir intervalos a string para eje X
grupo['tenure_interval'] = grupo['tenure_interval'].astype(str)

# Mapear valores binarios a etiquetas
grupo['AdultoMayor'] = grupo['SeniorCitizen'].map({0: 'No', 1: 'Sí'})

# Crear gráfico interactivo
fig = px.line(
    grupo,
    x='tenure_interval',
    y='ChurnCount',
    color='AdultoMayor',
    markers=True,
    labels={
        'tenure_interval': 'Meses de contrato (agrupados)',
        'ChurnCount': 'Cantidad de evasiones'
    },
    title='Cantidad de evasiones según permanencia y edad (adulto mayor)',
    color_discrete_map={
        'No': 'skyblue',
        'Sí': 'sandybrown'
    },
    hover_data={'AdultoMayor': False}  # Oculta esta columna del tooltip
)

# Ajustes visuales
fig.update_layout(
    xaxis_tickangle=-45,
    legend_title='Adulto mayor:',
    legend=dict(yanchor="top", y=0.99, xanchor="right", x=0.99)
)

plt.show()

fig.write_html("evasiones_permanencia_edad.html")
from google.colab import files
files.download("evasiones_permanencia_edad.html")

# %%
datos_churn_filtrados['TotalPayed'] = datos_churn_filtrados['ChargesMonthly'] * datos_churn_filtrados['tenure']
datos_churn_filtrados['TotalPayed'].sample(5)
# Out:
# /tmp/ipython-input-2469071529.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1146    5644.0
# 266      892.4
# 5541      46.3
# 2877    3422.5
# 6830    6230.0
# Name: TotalPayed, dtype: float64

# %%
# Total gastado
import pandas as pd
import numpy as np
import plotly.express as px

# Agrupar la permanencia (tenure) en intervalos de 6 meses
datos_churn_filtrados = datos_churn_filtrados.copy()
max_pago = np.ceil(datos_churn_filtrados['TotalPayed'].max()).astype(int)
datos_churn_filtrados['TotalPayed_interval'] = pd.cut(datos_churn_filtrados['TotalPayed'], bins=range(0, max_pago, 500))

# Calcular la cantidad de personas que evadieron (Churn == 1)
grupo = datos_churn_filtrados[datos_churn_filtrados['Churn'] == 1] \
    .groupby(['TotalPayed_interval', 'SeniorCitizen'], observed=True) \
    .size().reset_index(name='ChurnCount')

# Convertir intervalos a string para eje X
grupo['TotalPayed_interval'] = grupo['TotalPayed_interval'].astype(str)

# Mapear valores binarios a etiquetas
grupo['AdultoMayor'] = grupo['SeniorCitizen'].map({0: 'No', 1: 'Sí'})

# Crear gráfico interactivo
fig = px.line(
    grupo,
    x='TotalPayed_interval',
    y='ChurnCount',
    color='AdultoMayor',
    markers=True,
    labels={
        'TotalPayed_interval': 'Valor pagado (agrupado)',
        'ChurnCount': 'Cantidad de evasiones'
    },
    title='Cantidad de evasiones según valor pagado y edad (adulto mayor)',
    color_discrete_map={
        'No': 'skyblue',
        'Sí': 'sandybrown'
    },
    hover_data={'AdultoMayor': False}  # Oculta esta columna del tooltip
)

# Ajustes visuales
fig.update_layout(
    xaxis_tickangle=-45,
    legend_title='Adulto mayor:',
    legend=dict(yanchor="top", y=0.99, xanchor="right", x=0.99)
)

fig.show()

fig.write_html("evasiones_pagos_edad.html")
from google.colab import files
files.download("evasiones_pagos_edad.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **🚀 Informe final**

# %% [markdown]
# Finaliza el desafío elaborando un informe dentro del mismo notebook que resuma todo el trabajo realizado. El informe debe incluir:
#
# 🔹 Introducción: Explica el objetivo del análisis y el problema de evasión de clientes (Churn).
#
# 🔹 Limpieza y Tratamiento de Datos: Describe los pasos realizados para importar, limpiar y procesar los datos.
#
# 🔹 Análisis Exploratorio de Datos: Presenta los análisis realizados, incluyendo gráficos y visualizaciones para identificar patrones.
#
# 🔹 Conclusiones e Insights: Resume los principales hallazgos y cómo estos datos pueden ayudar a reducir la evasión.
#
# 🔹 Recomendaciones: Ofrece sugerencias estratégicas basadas en tu análisis.
#
# Asegúrate de que el informe esté bien estructurado, claro y respaldado por visualizaciones que refuercen tus conclusiones.

# %% [markdown]
# ### **Introducción**

# %% [markdown]
# Este estudio tiene como objetivo analizar la evasión de clientes en una compañía de servicios TelecomX, con el fin de comprender los factores asociados una alta tasa de cancelaciones del servicio. Se investigaron variables como el tipo de contrato, método de pago, género, edad (adulto mayor) y el comportamiento financiero (permanencia y total pagado). La visualización y análisis de estos patrones permitirá desarrollar estrategias efectivas para aumentar la fidelización de los clientes.

# %% [markdown]
# ### **Limpieza y Tratamiento de Datos**

# %% [markdown]
# Se aplicaron las siguientes transformaciones:
#
# *   Eliminación de registros con valores nulos o inconsistentes, por ejemplo, excluyendo a los clientes cuyo estado de permanencia se desconoce, ya que estos tienen un porcentaje bajo que no influye en el análisis.
# *   Conversión de valores textuales como "Sí" y "No" en valores binarios (1 y 0) y tipo object a float.
# *   Renombración de columnas para que la información sea más accesible y fácil de entender.

# %% [markdown]
# ### **Análisis Exploratorio de Datos**

# %% [markdown]
# Principales hallazgos:
#
# *   El 42.7% de quienes tenían contrato mensual evadieron.
# *   La evasión es muy alta en clientes que llevan menos de 6 meses (tanto jóvenes como adultos mayores). Con el tiempo, la evasión disminuye progresivamente.
# *   Contratos anuales y bianuales muestran tasas de evasión menores (11.3% y 2.8%).
# *   Clientes que usan cheque electrónico tienen la mayor tasa de evasión (45.3%).
# *   Pagos automáticos (banco o tarjeta) retienen más clientes (83–85%).
# *   No hay diferencias relevantes en evasión entre hombres y mujeres (~26%).
# *   La mayoría de las evasiones se concentran en clientes que pagaron menos de $1000, especialmente menores de 65 años.
# *   A medida que el total pagado aumenta, la evasión disminuye drásticamente, indicando que clientes que han invertido más en el servicio están más comprometidos.
# *   Adultos mayores muestran menor evasión en todos los rangos.

# %% [markdown]
# ### **Conclusiones e Insights**

# %% [markdown]
# 1.   Contratos cortos y pagos manuales son factores de riesgo clave para la evasión.
# 2.   La edad es un factor importante: los adultos mayores tienen menor propensión a cancelar el servicio.
# 3.   La evasión es más probable en etapas iniciales (0–6 meses) o con bajo gasto acumulado.
# 4.   La relación entre compromiso financiero y retención es fuerte: más inversión → menor evasión.

# %% [markdown]
# ### **Recomendaciones**

# %% [markdown]
# Segun la área:
# 1.   Contratos -se recomienda a incentivar el cambio a contratos anuales o bianuales (descuentos, beneficios exclusivos).
# 2.   Pagos -se recomienda a fomentar pagos automáticos con promociones o bonificaciones.
# 3.   Atención a cliente -mejorar la experiencia en los primeros 6 meses, donde ocurre la mayor parte de la evasión.	Identificar a clientes jóvenes, con contrato mensual y bajo total pagado como grupo de riesgo. A los adultos mayores fortalecer la fidelización con planes específicos para este grupo, que ya muestra alta retención.

# %% [markdown]
# ## Como desafío adicional, crea un **README.md** para tu proyecto Telecom X, incluyendo:
#
# *   El propósito del análisis realizado.
# *   La estructura del proyecto y organización de los archivos.
# *   Ejemplos de gráficos e insights obtenidos.
# I*   nstrucciones para ejecutar el notebook.

# %% [markdown]
# # **Preparación técnica para Telecom X – Parte 2**

# %% [markdown]
# Verifica lo siguiente:
#
# ✅ ¿Los datos están limpios y estandarizados?
#
# ⚠️ ¿Aún existen valores nulos, filas duplicadas o cadenas vacías?
#
# 🧹 ¿El tipo de dato de cada columna está correcto (por ejemplo: fechas, números, categorías)?
#
# 📁 Si todo está en orden, este será el archivo que utilizarás en la segunda parte del challenge.
#
# 💾 Para exportar tu dataset limpio, utiliza:
#
# `df.to_csv('datos_limpios.csv', index=False)`

# %%
datos_churn_filtrados.to_csv('datos_churn_filtrados.csv', index=False)
